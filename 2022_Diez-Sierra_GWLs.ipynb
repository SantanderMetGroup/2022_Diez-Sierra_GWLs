# %% [markdown]
# # Consistency of regional response to global warming levels from CMIP5 and CORDEX projections
#
# ***
#
# > This notebook reproduces key figures available in the article "Consistency of regional response to global warming levels from CMIP5 and CORDEX projections". This work is licensed under a Creative Commons Attribution 4.0 International License.

# %% [markdown]
# ## Assessing regional rensponse to GWL from CMIP5 and CORDEX projections
#
# 16/06/2022
#
# *J. Diez-Sierra & J. Fernández*  - [Santander Meteorology Group](http://www.meteo.unican.es). Instituto de Física de Cantabria, CSIC-UC, Santander, Spain.
#
# Global Warming Level (GWL) plots summarize the regional climate sensitivity of changes in different variables as a function of global mean surface air temperature changes. Decadal mean changes for the different members of a multimodel ensemble provide the sample to study the relationship between regional climate sensitivity and GWL. These plots are generated by the IPCC WGI AR6 Interactive Atlas (http://interactive-atlas.ipcc.ch) and are reproduced in this notebook using the data available in the Atlas repository. As in the interactive Atlas, the notebook allows to set different variables (tas or pr), masks (land, sea, landsea), scenarios, reference regions, etc.

# %% [markdown]
# ### Import packages and functions

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import warnings
from pathlib import Path
from utils import *

# %% [markdown]
# ### Set parameters

# %%
kwargs = dict(
    region = 'MED', # check Iturbide et al., 2020 (Figure 1b)
    variable = 'pr', # [pr or tas]
    season = 'DJF', # [DJF, MAM, JJA, SON or Annual]
    mask = 'landsea', # [landsea land or sea]
    scenario = 'rcp85', # [rcp26, rcp45 or rcp85]
    scenario_common = False, # if true select only those simulations available at both rcp45 and rcp85 scenarios
    period_PI = slice('1850','1900'), # Pre-Industrial Period 
    period_CP = slice('1986', '2005'), # Control or modern Period
    GWL_limit = 6, # Control de GWL limit used in the analysis
    show_figure = True,
    dest = str(Path.cwd()) + '/delete/', # path to save the results
    root = '/home/javi/Research/GWL_CORDEX_CMIP5/Atlas/Atlas/') # root to the GitHub IPCC Atlas repository (https://github.com/IPCC-WG1/Atlas)
                                                                # clone the repository and change the root

# %% [markdown]
# ### CMIP5 vs CORDEX

# %%
with warnings.catch_warnings(record=True):
    if __name__ == '__main__':
        main(**kwargs)

# %% [markdown]
# ## Impact of the emission scenario

# %% [markdown]
# We select those model available from both rcp45 and rcp85.

# %%
with warnings.catch_warnings(record=True):
    kwargs['season'] = 'Annual'
    kwargs['GWL_limit'] = 3
    kwargs['variable'] = 'pr'
    kwargs['scenario_common'] = True
    for rcp in ['rcp45', 'rcp85']:
        kwargs['scenario'] = rcp
        main(**kwargs)

# %% [markdown]
# We select all models available from rcp85

# %%
with warnings.catch_warnings(record=True):
    kwargs['scenario_common'] = False
    kwargs['scenario'] = 'rcp85'
    main(**kwargs)

# %% [markdown]
# ### References

# %% [markdown]
# Iturbide, M., Gutiérrez, J. M., Alves, L. M., Bedia, J., Cerezo-Mota, R., Cimadevilla, E., Cofiño, A. S., Di Luca, A., Faria, S. H., Gorodetskaya, I. V., Hauser, M., Herrera, S., Hennessy, K., Hewitt, H. T., Jones, R. G., Krakovska, S., Manzanas, R., Martínez-Castro, D., Narisma, G. T., Nurhati, I. S., Pinto, I., Seneviratne, S. I., van den Hurk, B., and Vera, C. S.: An update of IPCC climate reference regions for subcontinental analysis of climate model data: definition and aggregated datasets, Earth Syst. Sci. Data, 12, 2959–2970, https://doi.org/10.5194/essd-12-2959-2020, 2020.
